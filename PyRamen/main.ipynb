# %%
import csv

# get menu data into a dictionary
with open('../PyRamen/menu_data.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)

    menu = {}
    for row in csvreader:
        menu[row[0]] = float(row[3]), float(row[4])
    print(menu)
# Out:
# {'edamame': (4.0, 1.0), 'house salad': (4.0, 2.0), 'cucumber sunomono salad': (5.0, 2.0), 'hiyashi wakame seaweed salad': (5.0, 2.0), 'agedashi tofu': (5.0, 2.0), 'hiyayakko tofu': (5.0, 2.0), 'pork floss bao': (4.0, 2.0), 'kakuni bao': (6.0, 3.0), 'edamame fried gyoza (vegan)': (6.0, 3.0), 'fried gyoza': (6.0, 6.0), 'takoyaki': (6.0, 3.0), 'rock shrimp tempura': (6.0, 3.0), 'soft-shell crab tempura': (6.0, 3.0), 'ebi katsu shrimp bao': (6.0, 3.0), 'nagomi shoyu': (11.0, 5.0), 'shio ramen': (11.0, 5.0), 'spicy miso ramen': (12.0, 5.0), 'vegetarian spicy miso': (12.0, 5.0), 'miso crab ramen': (12.0, 6.0), 'soft-shell miso crab ramen': (14.0, 7.0), 'tori paitan ramen': (13.0, 6.0), 'tonkotsu ramen': (13.0, 6.0), 'burnt garlic tonkotsu ramen': (14.0, 6.0), 'vegetarian curry + king trumpet mushroom ramen': (13.0, 7.0), 'truffle butter ramen': (14.0, 7.0), 'green tea': (2.5, 1.0), 'coke': (2.0, 1.0), 'black sesame ice cream': (5.0, 2.0), 'matcha ice cream': (5.0, 2.0), 'mango mochi ice cream': (5.0, 2.0), 'strawberry mochi ice cream': (5.0, 2.0), 'black sesame creme brulee': (6.0, 3.0)}

# %%
# get menu data into a dictionary
with open('../PyRamen/sales_data.csv', 'r') as csvfile:
    csvreader = csv.reader(csvfile)
    fields = next(csvreader)

    sales = []
    for row in csvreader:
        sales.append((int(row[3]), row[4]))
    print(sales)
# Out:
# [(1, 'spicy miso ramen'), (1, 'spicy miso ramen'), (3, 'tori paitan ramen'), (3, 'tori paitan ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'tonkotsu ramen'), (1, 'tonkotsu ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'shio ramen'), (1, 'shio ramen'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'spicy miso ramen'), (1, 'spicy miso ramen'), (2, 'truffle butter ramen'), (2, 'truffle butter ramen'), (2, 'tonkotsu ramen'), (2, 'tonkotsu ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (2, 'tori paitan ramen'), (2, 'tori paitan ramen'), (1, 'spicy miso ramen'), (1, 'spicy miso ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (4, 'tonkotsu ramen'), (4, 'tonkotsu ramen'), (4, 'miso crab ramen'), (4, 'miso crab ramen'), (1, 'miso crab ramen'), (1, 'miso crab ramen'), (1, 'nagomi shoyu'), (1, 'nagomi shoyu'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'soft-shell miso crab ramen'), (1, 'soft-shell miso crab ramen'), (3, 'nagomi shoyu'), (3, 'nagomi shoyu'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'shio ramen'), (1, 'shio ramen'), (2, 'nagomi shoyu'), (2, 'nagomi shoyu'), (1, 'soft-shell miso crab ramen'), (1, 'soft-shell miso crab ramen'), (1, 'tonkotsu ramen'), (1, 'tonkotsu ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'spicy miso ramen'), (1, 'spicy miso ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (2, 'soft-shell miso crab ramen'), (2, 'soft-shell miso crab ramen'), (4, 'spicy miso ramen'), (4, 'spicy miso ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (3, 'burnt garlic tonkotsu ramen'), (3, 'burnt garlic tonkotsu ramen'), (4, 'miso crab ramen'), (4, 'miso crab ramen'), (3, 'truffle butter ramen'), (3, 'truffle butter ramen'), (3, 'vegetarian spicy miso'), (3, 'vegetarian spicy miso'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'tonkotsu ramen'), (1, 'tonkotsu ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'tonkotsu ramen'), (1, 'tonkotsu ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'vegetarian curry + king trumpet mushroom ramen'), (1, 'vegetarian curry + king trumpet mushroom ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (3, 'truffle butter ramen'), (3, 'truffle butter ramen'), (1, 'nagomi shoyu'), (1, 'nagomi shoyu'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'vegetarian curry + king trumpet mushroom ramen'), (1, 'vegetarian curry + king trumpet mushroom ramen'), (1, 'spicy miso ramen'), (1, 'spicy miso ramen'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (1, 'tori paitan ramen'), (2, 'vegetarian spicy miso'), (2, 'vegetarian spicy miso'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'vegetarian curry + king trumpet mushroom ramen'), (1, 'vegetarian curry + king trumpet mushroom ramen'), (1, 'nagomi shoyu'), (1, 'nagomi shoyu'), (4, 'nagomi shoyu'), (4, 'nagomi shoyu'), (1, 'burnt garlic tonkotsu ramen'), (1, 'burnt garlic tonkotsu ramen'), (1, 'nagomi shoyu'), (1, 'nagomi shoyu'), (1, 'vegetarian spicy miso'), (1, 'vegetarian spicy miso'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'truffle butter ramen'), (1, 'shio ramen'), (1, 'shio ramen'), (1, 'vegetarian ...

# %%
# iterate through sales data and create a report of the profits and sales of each item sold
report = {}
for sale in sales:
    quantity, sales_item = sale
    price, cost = menu[sales_item]
    profit = price - cost
    
    if sales_item not in report:
        report[sales_item] = {}
        report[sales_item]["01-count"] = quantity
        report[sales_item]["02-revenue"] = price * quantity
        report[sales_item]["03-cogs"] = cost * quantity
        report[sales_item]["04-profit"] = profit * quantity
    else:
        report[sales_item]["01-count"] += quantity
        report[sales_item]["02-revenue"] += price * quantity
        report[sales_item]["03-cogs"] += cost * quantity
        report[sales_item]["04-profit"] += profit * quantity

print(report)
# Out:
# {'spicy miso ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'tori paitan ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'truffle butter ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'tonkotsu ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'vegetarian spicy miso': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'shio ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'miso crab ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'nagomi shoyu': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'soft-shell miso crab ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}}
